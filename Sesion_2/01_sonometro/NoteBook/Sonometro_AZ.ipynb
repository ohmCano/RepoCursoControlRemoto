# %% [markdown]
# # MEDIDOR DE NIVEL DE SONIDO (Título 1)
# ## MEDIDOR DE NIVEL DE SONIDO (Título 2)
#
# Compilar o ejecutar o convertir en texto bonito ->  SHIFT + ENTER
#
#
# AZ Instrument Corp. es un líder reconocido a nivel nacional para soluciones innovadoras de medidores de nivel de sonido . En los últimos 20 años, hemos construido nuestra reputación en nuestra capacidad de personalizar nuestras soluciones para satisfacer las necesidades únicas de nuestros clientes. Medidor de nivel de sonido de alta calidad y calidad superior con un diseño ergonómico único que permite una posición de sujeción más cómoda. Nuestra misión es esforzarnos por alcanzar la excelencia en todas las fases de nuestro negocio y garantizar la completa satisfacción del cliente.
# AZ Instrument Corp. cree en trabajar con nuestros clientes para agregar valor al observar la forma en que se usa el producto, sugiriendo mejoras en el diseño, proceso de fabricación, empaque o métodos de compra para maximizar su eficiencia. Póngase en contacto con nuestra oficina de ventas en Taiwán para hablar sobre la idoneidad del medidor de nivel de sonido para sus aplicaciones o envíenos un correo electrónico para obtener más información.
#
# ![image.png](attachment:image.png)
#
# Las categorías > Sonómetro > Mano > Sonómetro8921 AZ USB Interface Digital Sound Level Meter
# 8921 AZ
# Sonómetro
# Bienvenido a consultar las características , la aplicación, la especificación, el manual de funcionamiento y el certificado CE del detector de ruido digital de interfaz USB 8921 AZ de la siguiente manera
# Caracteristicas :
#
# Características profesionales del medidor de nivel de sonido 8921 AZ:
# * Cumple con IEC60651, estándar de clase tipo 2
# * Pantalla LCD súper grande de lujo con precio asequible
# * Absorbente de ruido de fondo único
# * Características con pantalla digital y gráfico de barras analógico
# * Rango automático / manual, rango de 6 medidas en 10 pasos
# * Modo de retención máxima y respuesta rápida / lenta
# * La ponderación del aire acondicionado es conmutable
# * Fácil de calibrar por calibrador estándar
# * Salida analógica AC / DC
# * Interfaz USB
#
#
# ## Aplicación del probador de ruido 8921 AZ:
# El medidor de nivel de sonido profesional 8921 AZ proporciona un rango automático o manual en seis rangos de medición de 30 a 130 dB. La unidad cumple con ANSI S1.4 e IEC60651, estándares de clase tipo 2, y presenta una resolución de 0.1 dB.
#
# Un absorbedor de ruido de fondo de 8921 AZ SLM permite al usuario medir los niveles de sonido con precisión incluso en presencia de un ruido de fondo alto.
#
# El medidor de nivel de sonido 8921 AZ permite al usuario seleccionar entre tiempos de respuesta rápidos y lentos, así como la ponderación de A&C. Las tomas en el medidor proporcionan salida analógica AZ y DC.
#
# El medidor de nivel de ruido portátil 8921 AZ se puede utilizar para mediciones acústicas (sonido que viaja a través del aire), que se había utilizado ampliamente en aplicaciones de HVAC (calefacción, ventilación y aire acondicionado) y relacionadas con la industria. El usuario puede capturar datos de nivel de sonido a través de la interfaz USB.
#
# El medidor de prueba de sonido digital Decibel AZ 8921 fue diseñado y fabricado por AZ Instrument, un fabricante con mucha experiencia en instrumentos de medición ambiental.
#
# # Especificación :
#
# Especificación del medidor de nivel de sonido 8921 AZ:
#
# Modelo	8921
# Rango de medida	Un peso: 30 ~ 130 dB
# C peso: 35 ~ 130 dB
# Pantalla digital (6 rangos)	30 ~ 80, 40 ~ 90, 50 ~ 100, 60 ~ 110, 70 ~ 120, 80 ~ 130 dB
# Resolución de pantalla digital	0.1 dB
# Tiempo de actualización digital	160 ms
# Barra cuasi-analógica (6 rangos)	30 ~ 80, 40 ~ 90, 50 ~ 100, 60 ~ 110, 70 ~ 120, 80 ~ 130 dB
# Resolución cuasi-analógica	1 dB
# Hora de actualización de la barra	40 ms
# Precisión a 94 dB, 1 kHz	± 1.5 dB
# Salida analógica	AC 0.707 Vrms (a escala completa): DC 10 mV / dB
# Micrófono	Dia 6mm micrófono de condensador eléctrico
# Rango de frecuencia	31.5 Hz ~ 8 KHz
# Duración de la batería	30 horas tipicas
# Parabrisas	SÍ
# Tamaño del LCD	62 (L) * 42 (W) mm
# Temperatura de funcionamiento	0 ~ 50 ℃
# RH operativa%	Humedad ＜ 80%
# Temperatura de almacenamiento	-20 ~ 50 ℃
# Almacenamiento RH%	Humedad ＜ 90%
# Tamaño del medidor	254 (L) * 77 (W) * 37 (H) mm
# Peso	~ 200g
# Batería	Batería de 9 V * 1 PC o adaptador de CC de 9 V
# Paquete estándar	Medidor, batería, manual, estuche
# Accesorio opcional	CD de software y cable USB
# Descargar :
# Bienvenido a descargar y verificar las especificaciones, el manual de operación y el certificado CE del instrumento de medición de sonido 8921 AZ desde el siguiente enlace del sitio web.

# %% [markdown]
# ## Manuales en PDF
#
# [url](dd.pdf)
# [8921Specification](pdf/8921 Specification.pdf)
#
# [8921Operation manual](./pdf/8921 Operation manual.pdf)
#
# [8921CECertificate](8921 CE Certificate.pdf)

# %% [markdown]
# NOTA: Los PDF tienen que estar en el directorio. Para encrustar un PDF hay que copiar la siguiente celda y sustituir la ruta:

# %%
from IPython.display import IFrame
IFrame("./pdf/8921 Specification.pdf", width=800, height=300)
# SHIFT + ENTER
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="./pdf/8921 Specification.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("./pdf/8921 CE Certificate.pdf", width=800, height=300)
# SHIFT + ENTER
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="./pdf/8921 CE Certificate.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <div align="center">
#     <iframe width="560" height="315"
#     src="https://youtube.com/embed/d1NK83vve6c"
#     </iframe>
# </div>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("d1NK83vve6c", width=400)

# %% [markdown]
# ![imagen de Auto Powe Off](Fotos/AutoPowerOff.PNG)

# %%
# Medida real de los datos del sonómetro conectado al PC

  #Hay que tener instalado la librería PySerial

# %% [markdown]
#  #Código de la librería para saber qué funciones tenemos disponibles.
# ```
#     def __init__(self, port):
#         self.port = port
#         self.ser = None
#         self.running = True
#         self.connected = True
#         self.sound_level = []
#
#     def get_sonometry(self):
#         if self.sound_level:
#             sound_level_max = max(self.sound_level)
#             sound_level_linear = [math.pow(10,x/20) for x in self.sound_level]
#             sound_level_mean = sum(sound_level_linear) / len(sound_level_linear)
#             sound_level_mean = 20*math.log10(sound_level_mean)
#         else:
#             sound_level_max = -1
#             sound_level_mean = -1
#
#         # Check if the AZ8922 is off.
#         # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
#
#         # Reset the arrays.
#         self.sound_level = []
#
#         # Round up.
#         sound_level_mean = round(sound_level_mean,2)
#
#         # logging.info(f'Sonometry AZ8922:{sound_level_mean}')
#         # logging.info('Sonometry AZ8922:%f' % sound_level_mean)
#         # if not self.connected: logging.warning('AZ8922 is disconnected.')
#
#         return sound_level_mean, sound_level_max
#
#     def run_thread(self):
#         thread = threading.Thread(target=self.sonometro_thread, daemon=True)
#         thread.start()
#
#     def stop_thread(self):
#         self.running = False
#         self.connected = False
#         if self.ser is not None: self.ser.close()
#
#     def sonometro_thread(self):
#         while self.running:
#             try:
#                 # If disconnected, check connection every 5 seconds.
#                 if not self.connected: time.sleep(5)
#                 self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
#                 self.connected = True
#
#                 while(self.connected and self.ser.in_waiting and self.running):
#                     output = self.ser.readline().decode('utf-8', 'ignore')
#                     output = output.strip()
#                     if output.startswith('N:') and output.endswith('dB'):
#                         self.sound_level.append(float(output.split(':')[1].split('dB')[0]))
#
#             except (serial.serialutil.SerialException, OSError):
#                 # Thread is not halted upon sensor disconnection.
#                 self.connected = False
# ```

# %%
#Para que las funciones externas se recarguen. Muy útil por si hacemos cambios en el códfigo de éstas.

# %load_ext autoreload
# %autoreload 2

# %%
#Para ver qué variables tenemos definidas

# %whos
# Out:
# Variable       Type      Data/Info
# ----------------------------------
# output         str       N:045.4dB
# port_AZ8922    str       COM2
# salida_texto   float     45.4
# ser            Serial    Serial<id=0x2e438e722b0, <...>scts=False, dsrdtr=False)
# serial         module    <module 'serial' from 'D:<...>es\\serial\\__init__.py'>
# x              int       9

# %%
locals()         # get the full dictionary
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM2\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   "#Para ver qué variables tenemos definidas\n\nget_ipython().run_line_magic('whos', '')",
#   'locals()         # get the full dictionary'],
#  '_oh': {},
#  '_dh': ['D:\\SW\\Programacion\\Python\\WPy64-3920\\notebooks\\Curso_Python_Control_Remoto\\Sesion_2\\01_sonometro\\NoteBook'],
#  'In': ['',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM2\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#   "#Para ver qué variables tenemos definidas\n\nget_ipython().run_line_magic('whos', '')",
#   'locals()         # get the full dictionary'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002E438D7B730>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x2e438dcdbb0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x2e438dcdbb0>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '_i': '#Para ver qué variables tenemos definidas\n\n%whos',
#  '_ii': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM2\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_iii': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i1': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  'serial': <module 'serial' from 'D:\\SW\\Programacion\\Python\\WPy64-3920\\python-3.9.2.amd64\\lib\\site-packages\\serial\\__init__.py'>,
#  'port_AZ8922': 'COM2',
#  'ser': Serial<id=0x2e438e722b0, open=False>(port='COM1', baudrate=2400, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False),
#  'x': 9,
#  'output': 'N:045.4dB',
#  'salida_texto': 45.4,
#  '_i2': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i3': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i4': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i5': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i6': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i7': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i8': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i9': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i10': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM1\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i11': 'import serial\n\n# Sound level meter.\n#port_AZ8922 = \'/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0\'\nport_AZ8922 = \'COM2\'\n\nser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port\n\n#while(ser.connected):\nfor x in range(10):\n    output = ser.readline().decode(\'utf-8\', \'ignore\')\n    output = output.strip()\n    #print("RS232 read data:"+str(output)+"\\n")\n    if output.startswith(\'N:\') and output.endswith(\'dB\'):\n        salida_texto=float(output.split(\':\')[1].split(\'dB\')[0])\n        print("RS232 db="+str(salida_texto)+"\\n")     \n    \nser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el \n#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia\n#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.',
#  '_i12': '#Para ver qué variables tenemos definidas\n\n%whos',
#  '_i13': 'locals()         # get the full dictionary'}

# %%
# just functions
# %who function
# Out:
# No variables match your requested type.

# %%
globals()['var'] # grab out a single value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-feb727480459> in <module>
# ----> 1 globals()['var'] # grab out a single value
#
# KeyError: 'var'

# %%
#Borrar Variables

del var2
# %whos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d6261da55abe> in <module>
#       1 #Borrar Variables
#       2
# ----> 3 del var2
#       4 get_ipython().run_line_magic('whos', '')
#
# NameError: name 'var2' is not defined

# %% [markdown]
# ![image.png](attachment:af720be0-6472-4576-b5cb-111e800a138d.png)

# %%
import time
import collections  # Ordered Dictionary.
import logging
import requests # pylint: disable=E0401

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')
# Handlers.

import AZ8922

# User Params.
SERIALNO = "HEIMDALSTA2"
LCD_TITLE = 'RUIDO DE FONDO V0.6'  # LCD Title. Max of 20 characters.
MEASURE_PERIOD = 3  # How often (seconds) we poll for measurements.
LCD_PERIOD = 10  # How often (seconds) the LCD switches between screens.
log_file = 'log_files/log.txt'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM2'

#Llamada a la función y crea objeto de la clase AZ8922
sound_level_meter = AZ8922.AZ8922(port_AZ8922)
sound_level_meter.run_thread()


# Main thread.
for x in range(10):

        # Inintialize the JSON object.
        #json_data = collections.OrderedDict()
        time.sleep(MEASURE_PERIOD)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level = sound_level_meter.get_sonometry()
        print(Magenta +"Medida(media, máximo)="+ str(sound_level)+ " dB\n")
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()
# Out:
# AZ8922: Iniciando la clase.
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB
#
# Medida(media, máximo)=(-1, -1) dB

# %%
import threading
import time
import math
import serial  #Hay que tener instalado la librería PySerial

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')

class AZ8922:

    def __init__(self, port):
        self.port = port
        self.ser = None
        self.running = True
        self.connected = True
        self.sound_level = []
        print(Red+"AZ8922: Iniciando la clase.\n",flush=True)

    def get_sonometry(self):
        if self.sound_level:
            sound_level_max = max(self.sound_level)
            sound_level_linear = [math.pow(10,x/20) for x in self.sound_level] 
            sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
            sound_level_mean = 20*math.log10(sound_level_mean) 
        else:
            sound_level_max = -1
            sound_level_mean = -1
            
        # Check if the AZ8922 is off.
        # if self.connected and not self.sound_level: logging.warning('AZ8922 is off.')
        
        # Reset the arrays.
        self.sound_level = []
        
        # Round up.
        sound_level_mean = round(sound_level_mean,2)
        
        # logging.info(f'Sonometry AZ8922:{sound_level_mean}') 
        # logging.info('Sonometry AZ8922:%f' % sound_level_mean) 
        # if not self.connected: logging.warning('AZ8922 is disconnected.')
         
        return sound_level_mean, sound_level_max

    def run_thread(self):
        thread = threading.Thread(target=self.sonometro_thread, daemon=True)
        thread.start()

    def stop_thread(self):
        self.running = False
        self.connected = False
        if self.ser is not None:
            self.ser.close()
            print(Red+"RS232 cerrando el puerto serie.\n",flush=True)
            

    def sonometro_thread(self):
        while self.running:
            try:
                # If disconnected, check connection every 5 seconds.
                if not self.connected: time.sleep(5)
                self.ser = serial.Serial(self.port, 2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)
                self.connected = True
                print(Red+"RS232 abriendo el puerto serie.\n",flush=True)

                #Para sacar valores intermedios
                #print("Self.conected="+str(self.connected)+"\n")
                #print("self.ser.in_waiting="+str(self.ser.in_waiting)+"\n")
                #print("self.running="+str(self.running)+"\n")
                
                #while(self.connected and self.ser.in_waiting and self.running):
                while(self.connected and self.running):
                    output = self.ser.readline().decode('utf-8', 'ignore')
                    output = output.strip()
                    print(Red+"RS232 read data:"+str(output)+"\n",flush=True)
                    if output.startswith('N:') and output.endswith('dB'):
                        self.sound_level.append(float(output.split(':')[1].split('dB')[0]))

            except (serial.serialutil.SerialException, OSError):
                # Thread is not halted upon sensor disconnection.
                self.connected = False
#_____________________________________________________________________________________________________________________

# User Params.
MEASURE_PERIOD = 3  # How often (seconds) we poll for measurements.
log_file = 'log_files/log.txt'

# Initialization.
logging.getLogger("urllib3").setLevel(logging.WARNING) # Disable DEBUG from the "requests" module.
logging.basicConfig(format='%(levelname)s:%(asctime)s %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S', filename=log_file, level=logging.DEBUG)

running = True  # Thread running condition.


# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM2'

#Llamada a la función y crea objeto de la clase AZ8922
sound_level_meter = AZ8922(port_AZ8922)

print(Blue+"Arrancamos el proceso para medir.\n")
sound_level_meter.run_thread()


# Main thread.
for x in range(10):

        # Inintialize the JSON object.
        #json_data = collections.OrderedDict()
        time.sleep(MEASURE_PERIOD)

        # Polling. Esta función devuelve: sound_level_mean, sound_level_max
        sound_level = sound_level_meter.get_sonometry()
        print(Blue+"Valor medido "+ str(sound_level)+ " dB\n")
        
# Stop the threads gracefully (close serial ports, clean LCD, etc).
logging.debug('Executing finally clause.')
running = False
sound_level_meter.stop_thread()
# Out:
# AZ8922: Iniciando la clase.
#
# Arrancamos el proceso para medir.
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB
#
# Valor medido (-1, -1) dB

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y printeo de los datos.

# %%
import serial

# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM5'

ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port

#while(ser.connected):
for x in range(1):
    output = ser.readline().decode('utf-8', 'ignore')
    print("Comando recibido: "+output)
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    #Nos aseguramos de que el comando está bien
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.
# Out:
# Comando recibido: N:065.2dB
#
# RS232 db=65.2

# %% [markdown]
# ## Ejemplo de lectura directa del Serial y almacenamiento en un vector.

# %%
import serial
import math

#Listado de colores para que el texto salga bonito por pantalla.
Red = '\033[91m'
Green = '\033[92m'
Blue = '\033[94m'
Cyan = '\033[96m'
White = '\033[97m'
Yellow = '\033[93m'
Magenta = '\033[95m'
Grey = '\033[90m'
Black = '\033[90m'
Default = '\033[99m'
#You can chain these to get different colors on the same line.
#print('\033[91m' + 'Red  ' + "\033[95m" + 'Magenta  ' + '\033[94m' + 'Blue')
#print(Red + 'Red  ' + Magenta + 'Magenta  ' + Blue + 'Blue  ')

# Sound level meter.
#port_AZ8922 = '/dev/serial/by-id/usb-Prolific_Technology_Inc._USB-Serial_Controller_D-if00-port0'
port_AZ8922 = 'COM5'

ser = serial.Serial(port_AZ8922,2400, serial.EIGHTBITS, serial.PARITY_NONE, serial.STOPBITS_ONE)  # open serial port

# Reset the arrays.
sound_level = []

#while(ser.connected):
for x in range(10):
    output = ser.readline().decode('utf-8', 'ignore')
    output = output.strip()
    #print("RS232 read data:"+str(output)+"\n")
    if output.startswith('N:') and output.endswith('dB'):
        salida_texto=float(output.split(':')[1].split('dB')[0])
        sound_level.append(salida_texto)
        print("RS232 db="+str(salida_texto)+"\n")     
    
ser.close()  #Cerramos el puerto porque no puede quedar cerrado. En el caso de que al ejecutar el código el 
#Serial se quede abierto y no se pueda volver a ejecutar el código porque el puerto está abierto. Se copia
#esta línea en una ventana nueva y se ejecuta. Con eso se cierra el Serial y ya se puede volver a abrir.

# Round up.
#sound_level_mean = round(sound_level_mean,2)
#print("Sound Level(Media)="+str(sound_level_mean)+"\n") 

#Calculamos el máximo en dB
sound_level_max = max(sound_level)
print(Green + "Sound Level(Max)="+str(sound_level_max)+" db\n") 

#Calculamos el mínomo en dB
sound_level_min = min(sound_level)
print(Magenta+"Sound Level(Min)="+str(sound_level_min)+" db\n") 

#Calculamos la suma de los valores sin decibelios
sound_level_linear = [math.pow(10,x/20) for x in sound_level] 
print(Blue +"Sound Level(linear)="+str(sound_level_linear)+"\n") 

#Pasamos la suma de lo medido en dB
sound_level_mean = sum(sound_level_linear) / len(sound_level_linear) 
sound_level_mean = 20*math.log10(sound_level_mean)
print(Red + "Sound Level(Mean)="+str(sound_level_mean)+" db\n")
# Out:
# RS232 db=72.2
#
# RS232 db=75.1
#
# RS232 db=60.5
#
# RS232 db=69.3
#
# RS232 db=70.8
#
# RS232 db=61.3
#
# RS232 db=65.8
#
# RS232 db=64.9
#
# RS232 db=72.9
#
# RS232 db=56.8
#
# Sound Level(Max)=75.1 db
#
# Sound Level(Min)=56.8 db
#
# Sound Level(linear)=[4073.8027780411303, 5688.529308438413, 1059.2537251772887, 2917.427014001166, 3467.368504525317, 1161.4486138403427, 1949.8445997580454, 1757.923613958693, 4415.70447353313, 691.8309709189363]
#
# Sound Level(Mean)=68.68599039281308 db

# %%
#Ploteo de los datos medidos

import matplotlib.pyplot as plt

plt.plot(sound_level,'b',sound_level,'bo') #Más opciones de plot aqui: https://matplotlib.org/tutorials/introductory/pyplot.html
plt.title('Sound Level samples measured during the test')
plt.ylabel('Sound Level [dB]')
plt.xlabel('Samples')
plt.grid()
plt.show()
