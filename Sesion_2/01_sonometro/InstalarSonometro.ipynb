# %% [markdown]
# Abrimos el instalador del software del fabricante del sonómetro:
#
# ![image.png](attachment:b1f3c93f-3bfc-4f50-9a24-cae3dfa33435.png)
#
# Install:
#
# ![image.png](attachment:53f26b30-af94-41a4-961f-555b516a4d20.png)
#
# Comprobar el puesto serie en el que se ha conectado el sonómetro:
#
# ![image.png](attachment:d7fb49a5-9fd0-404b-a639-dabd91f63b41.png)
#
# Configuramos los baudios al máximo y voilá
#
# ![image.png](attachment:b40a138d-469e-45be-9918-6f9414c81bf0.png)
