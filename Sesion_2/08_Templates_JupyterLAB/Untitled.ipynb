# %% [markdown]
# ![image.png](attachment:5e3bbe40-2a05-4bd7-870e-7d2fe34eef98.png)
#
# ![image.png](attachment:edf3689c-cc2c-4daf-9eea-69abe54572b7.png)
#
# ![image.png](attachment:9af1bac4-a34c-45c8-947b-95d1a073e068.png)
