# %% [markdown]
# # Instalar el módulo VARIABLE INSPECTOR

# %% [markdown]
# # Install
#
# En la ventana del Terminal,
#
# ![image.png](imagenes/abir_terminal.PNG)
#
# donde tenemos nuestro path con nuestro Python ejecutamos solo:
#
# ```
# jupyter labextension install @lckr/jupyterlab_variableinspector
# ```
#
# y después para ver si está instalado:
#
# ```
# PS C:\Users\Usuario\Downloads\winpython\WPy64-3810\notebooks> jupyter labextension list
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #Para activarlo, en la ventana de código hacemos: RMB
#
# ![image.png](attachment:image.png)
#
#
# ## Procedimientos de Uso
#
# ![image.png](./imagenes/early_demo.gif)

# %%
import numpy as np

# %%
foo="bar"

# %%
baz=True

# %%
matrix = np.random(10,10)

# %%
v=1

# %%
del foo

# %% [markdown]
# # Otros paquetes
#
# [Más información de paquetes para Ciencia](https://medium.com/@subpath/jupyter-lab-extensions-for-data-scientist-e0d97d529fc1)
#
# ## jupyter labextension install @jupyterlab/plotly-extension
# ## jupyter labextension install @mflevine/jupyterlab_html
# ## jupyter labextension install @jupyterlab/latex

# %% [markdown]
# # LATEX
#
# Pero hay que hacer una llamada al PATH del LATEX para que funcione.
# He creado "Jupyter_Lab.bat" para que funcione.
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exportar en PDF
#
# Hace falta instalar:
#
# pip install nbconvert
# pip install pandoc
#
# Con esto me ha dado error en la ventana del terminal de que pandoc no está.
# Entonces me voy a la página de PANDOC y me descargo (https://github.com/jgm/pandoc/releases/tag/2.9.2.1) el portable (ZIP) y copio los dos ficheros en el directorio:  d:\SW\Programacion\Python\WPy64-3741\python-3.7.4.amd64\
#
# AHora ya solo me da el error de que el LATEX no está en el PATH (SError: xelatex not found on PATH, if you have not installed xelatex you may need to do so. Find further instructions at https://nbconvert.readthedocs.io/en/
# latest/install.html#installing-tex.)
#
# PAra ello ejecuto el LAB_Jupyter.bat.
#
#
# jupyter nbconvert --execute my_notebook.ipynb --to pdf
#
# Pero si hay imágenes con PATH relativo el LATEX parece que se llama desde otro PATH y da errores.
# Si se le da a exportar a LATEX y se compila, no da problemas.
# Si hay tildes se recomienda añadir: \usepackage[utf8]{inputenc}
#
#
# pero da un error... tanto así como en FILE Export.
