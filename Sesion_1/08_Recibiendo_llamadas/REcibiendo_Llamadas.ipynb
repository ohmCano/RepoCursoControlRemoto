# %% [markdown]
# # Procedimiento de Uso de Microsip
#
# Descargamos el PORTABLE:  https://www.microsip.org/downloads
#
# ![image.png](attachment:5f5951fe-cc82-4be1-9b96-9c27906e9fba.png)
#
# Nos vamos a la WEB de la UGR de la Centralita:   pbx.ugr.es
#
# ![image.png](attachment:860af71f-db08-4a30-8297-77a8b96069d1.png)
#
# Nos identificamos
#
# ![image.png](attachment:1873cdc4-28d6-4e8c-b067-2a03bfe14543.png)
#
# Nos vamos a la pestaña softtone
#
# ![image.png](attachment:d6b8d728-905c-4454-a7c9-0a064ef3f5b0.png)
#
# Abrimos las propiedades.
#
# ![image.png](attachment:cfc1ae55-d578-49c5-b7f9-c194405e62bd.png)
#
# y rellenamos los datos obtenidos de la WEB de la Centralita Asterix de VOZ IP.
#
# ![image.png](attachment:910ffed7-d0c7-408b-bc4d-868a9dde36e0.png)
