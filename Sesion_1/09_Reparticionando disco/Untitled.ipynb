# %% [markdown]
# # Generar una partición de disco en C
# Vamos a dividir el disco C en dos partes. La partición C con Windows y la partición D para datos.
# En el caso de ejecutar una restauración del sistema creo que windows te preguntará.
# ![image.png](attachment:f5dab39f-ca1c-4276-aa77-acfa4098b0a9.png)
# ![image.png](attachment:1d9819d5-c57d-47cd-931c-78947bb40264.png)
# Crear un nuevo volumen con las opcioens por defectoD
# ![image.png](attachment:34439fd2-52db-4ee8-8f09-4fed4903c050.png)

# %% [markdown]
# Para hacer andar el portable hay que ejecutar el archivo:make_winpython_movable en el CMD
